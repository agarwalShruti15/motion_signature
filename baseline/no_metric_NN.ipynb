# %%
# %load_ext autoreload
# %autoreload 2

from repo import *
import numpy as np
import seaborn as sns
from sklearn.metrics import roc_curve, auc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
repo = Repo_Time_NN('/data/home/shruti/voxceleb/fabnet/vox2_test_mp4', 
                    '/data/home/shruti/voxceleb/fabnet/vox2_test_mp4/voxceleb_100_test.txt', 25)

# %%
out_df = repo.recall_at_k(False)

# %%
len(np.argwhere(np.array(out_df['pred_label']) == np.array(out_df['true_label'])).ravel())/len(out_df)
# Out:
# 0.8672801521593198

# %%
out_df.iloc[:200]
# Out:
#      pred_label  true_label      dist    index
# 0           0.0         0.0  0.004304    173.0
# 1           0.0         0.0  0.004833    174.0
# 2         112.0         0.0  0.008635  33992.0
# 3           0.0         0.0  0.006176      7.0
# 4           0.0         0.0  0.007325      8.0
# ..          ...         ...       ...      ...
# 195         1.0         1.0  0.005078    197.0
# 196        86.0         1.0  0.008907  25699.0
# 197         1.0         1.0  0.004633    201.0
# 198         1.0         1.0  0.005078    195.0
# 199         1.0         1.0  0.004901    191.0
#
# [200 rows x 4 columns]

# %%
out_df.to_csv('result_csv/25frames_no_metric.csv')

# %%
repo1 = Repo_Time_NN('/data/home/shruti/voxceleb/fabnet/vox2_test_mp4', 
                    '/data/home/shruti/voxceleb/fabnet/vox2_test_mp4/voxceleb_100_test.txt', 1)
# Out:
# (35752, 256)

# %%
out_df1 = repo1.recall_at_k(False)

# %%
len(np.argwhere(np.array(out_df1['pred_label']) == np.array(out_df1['true_label'])).ravel())/len(out_df1)
# Out:
# 0.859224658760349

# %%
out_df1
# Out:
#        pred_label  true_label      dist    index
# 0             0.0         0.0  0.277273    173.0
# 1             0.0         0.0  0.273146    174.0
# 2            98.0         0.0  0.420799  28915.0
# 3             0.0         0.0  0.262876      3.0
# 4             0.0         0.0  0.262876      3.0
# ...           ...         ...       ...      ...
# 35747       117.0       117.0  0.133477  35707.0
# 35748       117.0       117.0  0.174245  35540.0
# 35749       117.0       117.0  0.275988  35577.0
# 35750       117.0       117.0  0.280092  35750.0
# 35751       117.0       117.0  0.280092  35750.0
#
# [35752 rows x 4 columns]
